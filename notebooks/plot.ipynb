# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../data/rfm_data.csv')
df.head()
# Out:
#    CustomerID  Recency  Frequency  Moneytary
# 0   101000281      0.0   0.030488   0.143221
# 1   101000282      0.0   0.018293   0.010731
# 2   101000283      0.0   0.024390   0.013413
# 3   101000320      0.0   0.000000   0.005365
# 4   101000325      0.0   0.000000   0.026923

# %%
fig, ax = plt.subplots(figsize=(12, 4), ncols=3, nrows=1)
sns.histplot(df, x='Recency', bins=30, ax=ax[0])
sns.histplot(df, x='Frequency', bins=50, ax=ax[1])
sns.histplot(df, x='Moneytary', bins=30, ax=ax[2])
plt.show()

# %%
sns.histplot(df, x='Moneytary')
plt.show()

# %%
sns.histplot(df, x='Frequency')
plt.show()

# %%
cluster_kmeans = pd.read_csv('../data/cluster_kmeans.csv')
cluster_kmeans
# Out:
#        CustomerID  Recency  Frequency  Moneytary  Cluster Label
# 0       101000281    0.000      0.010   0.076623              1
# 1       101000282    0.000      0.006   0.005741              1
# 2       101000283    0.000      0.008   0.007176              1
# 3       101000320    0.000      0.000   0.002870              1
# 4       101000325    0.000      0.000   0.014404              1
# ...           ...      ...        ...        ...            ...
# 12359   107000620    0.137      0.000   0.008231              0
# 12360   107000623    0.137      0.000   0.001435              0
# 12361   107000624    0.137      0.000   0.008231              0
# 12362   107000625    0.137      0.000   0.008231              0
# 12363   107000626    0.137      0.000   0.008231              0
#
# [12364 rows x 5 columns]

# %%
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(projection='3d')

label = cluster_kmeans['Cluster Label']
for cluster_label in label.unique():
    cluster_data = cluster_kmeans[label == cluster_label]
    ax.scatter(cluster_data.Recency,
               cluster_data.Frequency,
               cluster_data.Moneytary, label=f'Cluster {cluster_label}')

ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Moneytary')

plt.legend(loc='best')
plt.savefig('3d.jpg')
plt.show()

# %%
sns.pairplot(df.iloc[:, 1:])
plt.savefig('pairplot.jpg')
plt.show()
